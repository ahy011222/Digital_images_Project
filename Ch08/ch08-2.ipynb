# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img1 = cv2.imread('/content/gdrive/MyDrive/digital/Images/scan.jpg')
RGB_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
cv2_imshow(gimg)
#plt.imshow(gimg1, cmap='gray')
# Out:
# (210, 726)
# <PIL.Image.Image image mode=L size=726x210>

# %% [markdown]
# erode는 원래 하얀색을 줄이는 건데 이 사진의 경우에는 하얀색을 줄이니까 오히려 검정색이 더 커보인다.
# dilate는 원래 하얀색을 키우는 건데 이 사진의 경우에는 하얀색을 더 키워보이니까 오히려 검정색이 더 연해보인다.
# 검은색을 없에는 게 목적.

# %%
kernel = np.ones((4,1), np.uint8)
dilateImg = cv2.dilate(gimg, kernel, iterations = 2)
cv2_imshow(dilateImg)
# Out:
# <PIL.Image.Image image mode=L size=726x210>

# %%
kernel = np.ones((4,1), np.uint8)
erodeImg = cv2.erode(gimg, kernel, iterations = 1)
cv2_imshow(erodeImg)
# Out:
# <PIL.Image.Image image mode=L size=726x210>

# %%
img1 = cv2.imread('/content/gdrive/MyDrive/digital/Images/fce(salt_pepper noise).bmp')
RGB_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
cv2_imshow(gimg)
#plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
dilateimg = cv2.dilate(gimg, kernel, iterations = 1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3), np.uint8)
erodeimg = cv2.erode(dilateimg, kernel, iterations = 2)
cv2_imshow(erodeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
