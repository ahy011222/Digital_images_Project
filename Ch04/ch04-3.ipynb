# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img1 = cv2.imread('/content/gdrive/MyDrive/digital/Images/lena256.jpg')
RGB_img = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

gimg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gimg.shape)
cv2_imshow(gimg)
#plt.imshow(gimg1, cmap='gray')
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gimg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
gOut = cv2.equalizeHist(gimg)
cv2_imshow(gOut)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gist = cv2.calcHist([gOut], [0], None, [256], [0, 256])
plt.plot(hist)
print(hist.shpae)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-cc13aea3a304> in <cell line: 3>()
#       1 gist = cv2.calcHist([gOut], [0], None, [256], [0, 256])
#       2 plt.plot(hist)
# ----> 3 print(hist.shpae)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'shpae'

# %%
cumulHist = hist.copy()

for i in range(1, 256):
  cumulHist[i] = cumulHist[i-1] + hist[i]

plt.plot(cumulHist)

# %%
gist = cv2.calcHist([gimg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
cumulHist = hist.copy()

for i in range(1, 256):
  cumulHist[i] = cumulHist[i-1] + hist[i]

plt.plot(cumulHist)

# %%
equalHist = cumulHist.copy()
num0fPixels = np.int32(gimg.shape[0] * gimg.shape[1])
equalHist = equalHist / num0fPixels

plt.plot(equalHist)

# %%
equalHist = equalHist * 256

plt.plot(equalHist)

# %%
gOut = gimg.copy()

for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    gOut[h, w] = equalHist[gimg[h, w]]

cv2_imshow(gOut)
# Out:
# <ipython-input-40-640c43f8683f>:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   gOut[h, w] = equalHist[gimg[h, w]]
# <PIL.Image.Image image mode=L size=256x256>

# %%
cumulHist = hist.copy()

for i in range(1, 256):
  cumulHist[i] = cumulHist[i-1] + hist[i]

plt.plot(cumulHist)

# %%
hist = cv2.calcHist([gOut], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
cumulHist = hist.copy()

for i in range(1, 256):
  cumulHist[i] = cumulHist[i-1] + hist[i]

plt.plot(cumulHist)
