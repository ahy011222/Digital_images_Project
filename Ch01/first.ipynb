# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/gdrive/MyDrive/digital/cat.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x853>

# %%
print(img.shape)
# Out:
# (853, 1280, 3)

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
plt.imshow(img)
